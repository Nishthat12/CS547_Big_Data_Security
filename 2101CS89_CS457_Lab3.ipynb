# %% [markdown]
# ## Password Validator

# %%
import re

# Function to check password validity
def validate_password(password, criteria):
    if len(password) < 8:
        print(f'Password "{password}" is Invalid. Less than 8 Characters.')
        return False

    errors = []

    if '1' in criteria and not any(char.isupper() for char in password):
        errors.append("Missing Uppercase letters")
    if '2' in criteria and not any(char.islower() for char in password):
        errors.append("Missing Lowercase letters")
    if '3' in criteria and not any(char.isdigit() for char in password):
        errors.append("Missing Numbers")
    if '4' in criteria:
        if not re.search(r'[!@#]', password):
            errors.append("Missing Special characters (!, @, #)")
        if any(char in password for char in "$%^&*()-_+=:;,<>?/|\\[]{}~`"):
            errors.append("Contains disallowed special characters")

    if errors:
        print(f'Password "{password}" is Invalid. ' + ", ".join(errors))
        return False
    else:
        print(f'Password "{password}" is Valid.')
        return True

# User input for criteria
criteria_input = input("Select criteria (1: Uppercase, 2: Lowercase, 3: Numbers, 4: Special Characters): ")
selected_criteria = set(criteria_input.split(','))

# User choice for password input
choice = input("Do you want to enter passwords manually or use sample lists? (enter/sample): ")

if choice.lower() == "enter":
    passwords = input("Enter passwords separated by commas: ").split(',')
else:
    # Sample password lists for testing
    password_lists1=["abc12345", "abc", "123456789", "abcdefg$", "abcdefgABHD!@313", "abcdefgABHD$$!@313"]
    password_lists2=["Qwerty@123", "password", "P@ssword1", "Welcome123", "Hello!@#123", "HELLO123"]
    password_lists3=["Test@Pass1", "NoSpecial1", "Alllowercase@123", "ALLUPPERCASE#123", "Valid#Pass123", "Short1!"]

    passwords = password_lists3

print("\nChecking Passwords:\n")
for pwd in passwords:
    validate_password(pwd, selected_criteria)
# Out:
# Select criteria (1: Uppercase, 2: Lowercase, 3: Numbers, 4: Special Characters): 1,2,3,4
# Do you want to enter passwords manually or use sample lists? (enter/sample): sample
#
# Checking Passwords:
#
# Password "Test@Pass1" is Valid.
# Password "NoSpecial1" is Invalid. Missing Special characters (!, @, #)
# Password "Alllowercase@123" is Valid.
# Password "ALLUPPERCASE#123" is Invalid. Missing Lowercase letters
# Password "Valid#Pass123" is Valid.
# Password "Short1!" is Invalid. Less than 8 Characters.

# %% [markdown]
# # Password Validator for input file with 1000 sample passwords

# %%
import re

# Function to check password validity
def validate_password(password, criteria):
    if len(password) < 8:
        return False, "Less than 8 Characters"

    errors = []

    if '1' in criteria and not any(char.isupper() for char in password):
        errors.append("Missing Uppercase letters")
    if '2' in criteria and not any(char.islower() for char in password):
        errors.append("Missing Lowercase letters")
    if '3' in criteria and not any(char.isdigit() for char in password):
        errors.append("Missing Numbers")
    if '4' in criteria:
        if not re.search(r'[!@#]', password):
            errors.append("Missing Special characters (!, @, #)")
        if any(char in password for char in "$%^&*()-_+=:;,<>?/|\\[]{}~`"):
            errors.append("Contains disallowed special characters")

    if errors:
        return False, ", ".join(errors)
    else:
        return True, "Valid"

# User input for criteria
criteria_input = input("Select criteria (1: Uppercase, 2: Lowercase, 3: Numbers, 4: Special Characters): ")
selected_criteria = set(criteria_input.split(','))

# User choice for password input
choice = input("Do you want to enter passwords manually, use sample lists, or read from file? (enter/sample/file): ")

if choice.lower() == "enter":
    passwords = input("Enter passwords separated by commas: ").split(',')
elif choice.lower() == "sample":
    # Sample password lists for testing
    password_lists1=["abc12345", "abc", "123456789", "abcdefg$", "abcdefgABHD!@313", "abcdefgABHD$$!@313"]
    password_lists2=["Qwerty@123", "password", "P@ssword1", "Welcome123", "Hello!@#123", "HELLO123"]
    password_lists3=["Test@Pass1", "NoSpecial1", "Alllowercase@123", "ALLUPPERCASE#123", "Valid#Pass123", "Short1!"]

    passwords = password_lists1
elif choice.lower() == "file":
    with open("input.txt", "r") as file:
        passwords = [line.strip() for line in file.readlines()]
else:
    print("Invalid choice. Exiting.")
    exit()

valid_count = 0
invalid_count = 0

print("\nChecking Passwords:\n")
for pwd in passwords:
    is_valid, message = validate_password(pwd, selected_criteria)
    if is_valid:
        valid_count += 1
    else:
        invalid_count += 1
    print(f'Password "{pwd}" is {"Valid" if is_valid else "Invalid"}. {message}')

print(f"\nTotal Valid Passwords: {valid_count}")
print(f"Total Invalid Passwords: {invalid_count}")
# Out:
# Select criteria (1: Uppercase, 2: Lowercase, 3: Numbers, 4: Special Characters): 1,2,3,4
# Do you want to enter passwords manually, use sample lists, or read from file? (enter/sample/file): file
#
# Checking Passwords:
#
# Password "QToBq94lhU" is Invalid. Missing Special characters (!, @, #)
# Password "@r4LC4fVx93X!Na" is Valid. Valid
# Password "qKkEHME8lJRmiOoKAz" is Invalid. Missing Special characters (!, @, #)
# Password "zM#OkWZH@g4" is Valid. Valid
# Password "y11NVLQwg#EKwaUXBuaG" is Valid. Valid
# Password "oOqqoEvxWzU5" is Invalid. Missing Special characters (!, @, #)
# Password "D6k3lfOzXa#gQnmsjx8" is Valid. Valid
# Password "7ZRpku4Qb9xthP" is Invalid. Missing Special characters (!, @, #)
# Password "JdMehy1EL@9jsFjT" is Valid. Valid
# Password "fTzulhr5z2@" is Valid. Valid
# Password "M@7qz#ySZtT4b" is Valid. Valid
# Password "M@RT2pyD" is Valid. Valid
# Password "SOtIFU6#I" is Valid. Valid
# Password "@7HdSffQ5" is Valid. Valid
# Password "vDuweoaELkV" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "aCry@z#JYV" is Invalid. Missing Numbers
# Password "NbTn@P@k" is Invalid. Missing Numbers
# Password "3@1Uc1StlS" is Valid. Valid
# Password "KA6u8#x1Mx@" is Valid. Valid
# Password "8!2K94tA!swIv" is Valid. Valid
# Password "uB5055BSMCr" is Invalid. Missing Special characters (!, @, #)
# Password "!RdA2!maDeVV2N76" is Valid. Valid
# Password "Y94iQhx#ED68d" is Valid. Valid
# Password "Y!6Gh!Le@2tq" is Valid. Valid
# Password "ryQfIDZxqx" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "TGufESF5@f2RbeA68XcG" is Valid. Valid
# Password "7iS@Y!flFusi" is Valid. Valid
# Password "1HW#P#srq" is Valid. Valid
# Password "PIEhyrJgug" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "@!Mg5W8!7t8" is Valid. Valid
# Password "D8#iWl7WcMVmsipmD" is Valid. Valid
# Password "juiBWsefvk647MEs" is Invalid. Missing Special characters (!, @, #)
# Password "Gwvr9RmZIL5Pc6Sk6" is Invalid. Missing Special characters (!, @, #)
# Password "QadU@rKw5" is Valid. Valid
# Password "ZZdy@iNU" is Invalid. Missing Numbers
# Password "gv!EFfTn8!T" is Valid. Valid
# Password "HZ367VcNWhWM#NR" is Valid. Valid
# Password "2AHA62pbk@5G##q" is Valid. Valid
# Password "bwIBRuzzj17Ja" is Invalid. Missing Special characters (!, @, #)
# Password "n1y2Zjxn!xb" is Valid. Valid
# Password "CYy09MQsKpt3S" is Invalid. Missing Special characters (!, @, #)
# Password "0Jp!9zs@45O" is Valid. Valid
# Password "iguKjHD8ph" is Invalid. Missing Special characters (!, @, #)
# Password "2A1xZ#@i9" is Valid. Valid
# Password "7J8T57GrKG@U@VFDN" is Valid. Valid
# Password "mrR#anwErk3B" is Valid. Valid
# Password "CMmFq1O9HM" is Invalid. Missing Special characters (!, @, #)
# Password "2s1Bpb0@" is Valid. Valid
# Password "y@YKfBA0KITIOX7" is Valid. Valid
# Password "J#5oL3IOa" is Valid. Valid
# Password "ZZ70H3h@SW6oUIO" is Valid. Valid
# Password "sYe#msuOn@xZR" is Invalid. Missing Numbers
# Password "0Uf2Y3VVTRo4#" is Valid. Valid
# Password "7eV52JGxAj9WhL" is Invalid. Missing Special characters (!, @, #)
# Password "I6CJTXPSwx7KqkT3R" is Invalid. Missing Special characters (!, @, #)
# Password "VaprzfEz" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "2YryxAVE!K9" is Valid. Valid
# Password "B1knY44gcuA" is Invalid. Missing Special characters (!, @, #)
# Password "JvgW0CMh" is Invalid. Missing Special characters (!, @, #)
# Password "jrI42Ms@YO" is Valid. Valid
# Password "3D2Gm1vupKU" is Invalid. Missing Special characters (!, @, #)
# Password "z0sngtBDEBeOgdzMp" is Invalid. Missing Special characters (!, @, #)
# Password "Jwd5O@V8RmZk@" is Valid. Valid
# Password "FqaS89nmhcU" is Invalid. Missing Special characters (!, @, #)
# Password "eRi5IrYVYb@zNZXnO" is Valid. Valid
# Password "zbX#z!XKGJLbJ#" is Invalid. Missing Numbers
# Password "pE6IgQRq@r" is Valid. Valid
# Password "GpIrOHj9Ir9IIpp" is Invalid. Missing Special characters (!, @, #)
# Password "IBlLO6vtxlr!I" is Valid. Valid
# Password "lOnjzRyROX!1" is Valid. Valid
# Password "IOuL#aDkCBS6DxZN98" is Valid. Valid
# Password "4pE#qzX@a7ycUds" is Valid. Valid
# Password "4C@D2uRFbad@jQRq" is Valid. Valid
# Password "BjM4Oufsz9COIUVy" is Invalid. Missing Special characters (!, @, #)
# Password "whPtw@D" is Invalid. Less than 8 Characters
# Password "Wk#OMF3w2x" is Valid. Valid
# Password "bypoG22akfPmI3!LC" is Valid. Valid
# Password "@Xjs2ayiQpxa" is Valid. Valid
# Password "@qTpiF@zATKeB" is Invalid. Missing Numbers
# Password "CJdigmlwmW7" is Invalid. Missing Special characters (!, @, #)
# Password "zNZ#7LiDmCBlen3yn" is Valid. Valid
# Password "#qv8Y0ta#fhQFF" is Valid. Valid
# Password "Y1f1olGTPASCAjZe" is Invalid. Missing Special characters (!, @, #)
# Password "utrcnU69ZlucS!wL" is Valid. Valid
# Password "ILmIzzkHE9IbuIHc" is Invalid. Missing Special characters (!, @, #)
# Password "xpRgY3e" is Invalid. Less than 8 Characters
# Password "SwVcQ3ctRcAn!1ZFQJ" is Valid. Valid
# Password "r@TJBE0mdEf" is Valid. Valid
# Password "ao!8dl2zs0SDs" is Valid. Valid
# Password "L6okoWYy6lV!q" is Valid. Valid
# Password "o!1IucPTk@U0YnC1" is Valid. Valid
# Password "3LOL5ZlGXF" is Invalid. Missing Special characters (!, @, #)
# Password "5cBl@MEEAK#4k" is Valid. Valid
# Password "T40Ly6w#v#j" is Valid. Valid
# Password "lEWU#nRPO#z3" is Valid. Valid
# Password "pK0mWLW6J#!7!d" is Valid. Valid
# Password "8Y!uyi4ZPwN#5" is Valid. Valid
# Password "qLv38E@323#mx3X" is Valid. Valid
# Password "#o1Hyb!QJv" is Valid. Valid
# Password "HU#60xx##kk" is Valid. Valid
# Password "ChGeKwd#NMJRA" is Invalid. Missing Numbers
# Password "w0P2PV9mSpIqA!yvXv" is Valid. Valid
# Password "xP9ac15LD5cB" is Invalid. Missing Special characters (!, @, #)
# Password "5vv1A@5EAG" is Valid. Valid
# Password "Z7R2#4Uv7UYU6" is Valid. Valid
# Password "C7SYT!YAP9" is Invalid. Missing Lowercase letters
# Password "YPpDp6Wpv" is Invalid. Missing Special characters (!, @, #)
# Password "8Em3BtuYPBD" is Invalid. Missing Special characters (!, @, #)
# Password "5!awVTfRm#1Yj" is Valid. Valid
# Password "xzPVmhkY0PgxT7E" is Invalid. Missing Special characters (!, @, #)
# Password "SNb5Kxiu7bO57KuU" is Invalid. Missing Special characters (!, @, #)
# Password "HLAP1WQOYkEzt0iXLt" is Invalid. Missing Special characters (!, @, #)
# Password "UobTOv9xxl5" is Invalid. Missing Special characters (!, @, #)
# Password "!w7e0pdQuShtNUP" is Valid. Valid
# Password "1VfcXHhw6IjKK5" is Invalid. Missing Special characters (!, @, #)
# Password "F#ENU@5jAFY#tYI8Mq" is Valid. Valid
# Password "aDRpcN0c0hB@G7" is Valid. Valid
# Password "m7mJgFO" is Invalid. Less than 8 Characters
# Password "cMFFQ4aM" is Invalid. Missing Special characters (!, @, #)
# Password "vxuISkK2ceuvp3" is Invalid. Missing Special characters (!, @, #)
# Password "0QjbxO907qqE!vy" is Valid. Valid
# Password "EgkoDg33nv5bB7r" is Invalid. Missing Special characters (!, @, #)
# Password "K@5Cy3SWjll" is Valid. Valid
# Password "clVww6B" is Invalid. Less than 8 Characters
# Password "6T6S8u7@l" is Valid. Valid
# Password "56Kw!IiU" is Valid. Valid
# Password "TZPz4P#0lybwG" is Valid. Valid
# Password "QADL0wK5RB2!" is Valid. Valid
# Password "yGj9YGpg" is Invalid. Missing Special characters (!, @, #)
# Password "UnRS2K31@KZ3MAH" is Valid. Valid
# Password "c!Kp721U#H" is Valid. Valid
# Password "wWINHT6uLZX4EB6JI" is Invalid. Missing Special characters (!, @, #)
# Password "v8Tpbo6BzP75#AqVx" is Valid. Valid
# Password "!t3vgjlcNJl0b7D" is Valid. Valid
# Password "jhGO@u@EFQt" is Invalid. Missing Numbers
# Password "c8mF3Mh@DZ" is Valid. Valid
# Password "X17vkrntnErXg#" is Valid. Valid
# Password "9uB!0URlAb4#bMU" is Valid. Valid
# Password "upqCs5u6XraSGBfJR" is Invalid. Missing Special characters (!, @, #)
# Password "n9C4#R1" is Invalid. Less than 8 Characters
# Password "JUB!NZjmiK" is Invalid. Missing Numbers
# Password "oluhBUmS7U@" is Valid. Valid
# Password "pa#3@k9Ds#DHM" is Valid. Valid
# Password "AHdRb1hh2c" is Invalid. Missing Special characters (!, @, #)
# Password "xGEJWitSW#1d@UfEdX" is Valid. Valid
# Password "vBuSjv#OJoCw2" is Valid. Valid
# Password "nCcbLP6C" is Invalid. Missing Special characters (!, @, #)
# Password "p#Eu#k!NLw1k4BlTA8t" is Valid. Valid
# Password "6J1ad@y6n" is Valid. Valid
# Password "JFzHOr8#Cpbg4" is Valid. Valid
# Password "hAFnihxdO!6JN" is Valid. Valid
# Password "vm65w9HyM#bHd" is Valid. Valid
# Password "R8Pd2S@DmS" is Valid. Valid
# Password "axwY4kFVSti#4C3" is Valid. Valid
# Password "1@F3ZdTT#!4" is Valid. Valid
# Password "x!3Ism6lXS" is Valid. Valid
# Password "oquD2UfPi" is Invalid. Missing Special characters (!, @, #)
# Password "M2QN6FrCDw@dTZNk" is Valid. Valid
# Password "eH4EucbZF2" is Invalid. Missing Special characters (!, @, #)
# Password "2x@2pFbhonmY" is Valid. Valid
# Password "!PlY!@fXgFBTNlbvEW" is Invalid. Missing Numbers
# Password "6y5ZZEt#xj@X3eyZ" is Valid. Valid
# Password "dF1ce!4MhR9JwHM" is Valid. Valid
# Password "yT416dvzxQorBYx!Ub" is Valid. Valid
# Password "@Y3qwsOk!V4HM" is Valid. Valid
# Password "nk4MK762OQcG" is Invalid. Missing Special characters (!, @, #)
# Password "!i2w0q8nj3vs4" is Invalid. Missing Uppercase letters
# Password "aBax@pBeGgNdr" is Invalid. Missing Numbers
# Password "cILbQOMtBUXHnxHR" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "CiIu#NgB#lJK#" is Invalid. Missing Numbers
# Password "HQ5SgjrUS4" is Invalid. Missing Special characters (!, @, #)
# Password "trGJb9o9y" is Invalid. Missing Special characters (!, @, #)
# Password "Jlsu#LV3d5W#" is Valid. Valid
# Password "Umnn6dOYbxI" is Invalid. Missing Special characters (!, @, #)
# Password "nNEwJPdDQ!5jfhK0C" is Valid. Valid
# Password "Qgp@9H@j@o!v8xotvF" is Valid. Valid
# Password "nOT9Gdm" is Invalid. Less than 8 Characters
# Password "Sf68ZrHhP9pZ" is Invalid. Missing Special characters (!, @, #)
# Password "n5@9W8q@JE1#YzS" is Valid. Valid
# Password "fWKEVds79kQK" is Invalid. Missing Special characters (!, @, #)
# Password "@dPi5OhcaZx2M@k1" is Valid. Valid
# Password "@oSTYKuFG2XJF" is Valid. Valid
# Password "W9s@dfmWyyBsLK" is Valid. Valid
# Password "OeAfb#nuTcTd069VIZ" is Valid. Valid
# Password "lPuk06q!p!l!5" is Valid. Valid
# Password "fGM#QcS99qp" is Valid. Valid
# Password "hbyyPzt0p#L4Dd" is Valid. Valid
# Password "kTzdTcfOs5yi#9DTPc" is Valid. Valid
# Password "tVdt#f" is Invalid. Less than 8 Characters
# Password "2IvrX4PLK47HKeU4qY" is Invalid. Missing Special characters (!, @, #)
# Password "@NoArfbfhH!EWwZ2nk" is Valid. Valid
# Password "s3EPj@UQ3MqZT" is Valid. Valid
# Password "gt5azylN1!WdN" is Valid. Valid
# Password "X@aKoQg" is Invalid. Less than 8 Characters
# Password "dRByIFHczXlTWw" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "WWN@hnMY5oc" is Valid. Valid
# Password "3OpoO2BcnIx!" is Valid. Valid
# Password "oC5v6Bcd9dV" is Invalid. Missing Special characters (!, @, #)
# Password "LCOl@!f" is Invalid. Less than 8 Characters
# Password "o!LuGGBfW" is Invalid. Missing Numbers
# Password "GJmpfXQcuWQsE!iV" is Invalid. Missing Numbers
# Password "yTBgUDGzZihpZaL!#N" is Invalid. Missing Numbers
# Password "yD5B@uO6BQ" is Valid. Valid
# Password "9JWMiiN8PG" is Invalid. Missing Special characters (!, @, #)
# Password "Ij@RFpwQYAeF!m" is Invalid. Missing Numbers
# Password "n3jzExBW#!hm" is Valid. Valid
# Password "QLKPq8J2Uy" is Invalid. Missing Special characters (!, @, #)
# Password "GNH!aKw1PSTZ" is Valid. Valid
# Password "AQDQC!1VzTvscbQ" is Valid. Valid
# Password "AAUSqqxSo#" is Invalid. Missing Numbers
# Password "czmgrGhbQj@0h0v" is Valid. Valid
# Password "ZUT@pv7h9Hu" is Valid. Valid
# Password "yMid@rWhFAw" is Invalid. Missing Numbers
# Password "pjeY1pCc3@" is Valid. Valid
# Password "iZcwFKd2h" is Invalid. Missing Special characters (!, @, #)
# Password "jKufjd8u10@PVJ" is Valid. Valid
# Password "jpnCJUWh2A!CRFN" is Valid. Valid
# Password "Vn6QUjGsRhTt" is Invalid. Missing Special characters (!, @, #)
# Password "hc35@UT0#7MH" is Valid. Valid
# Password "2dY6OEGry5eJkM" is Invalid. Missing Special characters (!, @, #)
# Password "3sSDwIsOd!bc#93" is Valid. Valid
# Password "GLYrW6jJVFzO5ai@J" is Valid. Valid
# Password "PZanwt1BSQauYCdc@va" is Valid. Valid
# Password "jSb6zV009jdeM" is Invalid. Missing Special characters (!, @, #)
# Password "18N#OYijCymMPn#" is Valid. Valid
# Password "B4Ye5afCB" is Invalid. Missing Special characters (!, @, #)
# Password "y8OAn7Pa9VHdRT@" is Valid. Valid
# Password "Dfm0uOv!i7w2pnQL" is Valid. Valid
# Password "oTNq@iH41q!F" is Valid. Valid
# Password "pOnE9IDR3ea@apGA" is Valid. Valid
# Password "wzqNJR6n#x2" is Valid. Valid
# Password "RcRnHnyXggV9S" is Invalid. Missing Special characters (!, @, #)
# Password "eosJ0yKP" is Invalid. Missing Special characters (!, @, #)
# Password "CXsDhtGMVk" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "NrZnRC4l" is Invalid. Missing Special characters (!, @, #)
# Password "yRSnXMIKbHzc@n" is Invalid. Missing Numbers
# Password "d5lCu@09uTXYoJ9HUtF" is Valid. Valid
# Password "mA34RWSW8" is Invalid. Missing Special characters (!, @, #)
# Password "rIVSLgc2kXT!m" is Valid. Valid
# Password "P#YJSYUEq9KLx2gz#w" is Valid. Valid
# Password "sIQBl0p@5Hc" is Valid. Valid
# Password "y1Ax0BK!UZu" is Valid. Valid
# Password "KG7vKCZXMMHgcz#!" is Valid. Valid
# Password "w8VSTejO5B9" is Invalid. Missing Special characters (!, @, #)
# Password "dfVwck9dGiPbQB" is Invalid. Missing Special characters (!, @, #)
# Password "tFZmzOXV" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "Jjjaar6vC!" is Valid. Valid
# Password "eop5hB@@qvaJMzjVr" is Valid. Valid
# Password "FeqJkBm3#9GaUEwO" is Valid. Valid
# Password "GemfY3kjc1L@9!" is Valid. Valid
# Password "TT3#ZNi3" is Valid. Valid
# Password "eGcg6i3RJQJ7z1XS" is Invalid. Missing Special characters (!, @, #)
# Password "9hg6KcSKldhry3#3ZR" is Valid. Valid
# Password "ygmnso68H6Sng" is Invalid. Missing Special characters (!, @, #)
# Password "z0sy#6IkNJdkzVZz" is Valid. Valid
# Password "n!Skz#BC!PXZT2ld" is Valid. Valid
# Password "kpc34tQ!a" is Valid. Valid
# Password "BscnzqA" is Invalid. Less than 8 Characters
# Password "@u!ASD#nafgf" is Invalid. Missing Numbers
# Password "JZ6HLFFLlqXJZ@x@EI" is Valid. Valid
# Password "#5#QPxz" is Invalid. Less than 8 Characters
# Password "ICqwIS4Xle6vv" is Invalid. Missing Special characters (!, @, #)
# Password "!658#sHnirEseo" is Valid. Valid
# Password "vfw7XYEP" is Invalid. Missing Special characters (!, @, #)
# Password "MZnE2t@7RNh8bqt" is Valid. Valid
# Password "6Wiq@Qc#T1YrL" is Valid. Valid
# Password "ED6G891p!JNwKOe" is Valid. Valid
# Password "kQubQJrTlb!3ky" is Valid. Valid
# Password "douih19MN1k@g" is Valid. Valid
# Password "3M5E8#Zv" is Valid. Valid
# Password "hwMqY75@sn0" is Valid. Valid
# Password "JI830WFB1dl4Di28!aA" is Valid. Valid
# Password "qo7MizPs" is Invalid. Missing Special characters (!, @, #)
# Password "3NmLA05T" is Invalid. Missing Special characters (!, @, #)
# Password "T!RogNE" is Invalid. Less than 8 Characters
# Password "lKhLHKRKx@RsuNUE3!" is Valid. Valid
# Password "WO84fpgw!Yl!!C" is Valid. Valid
# Password "cj0piuBukEbXRhw" is Invalid. Missing Special characters (!, @, #)
# Password "42w#07z#PQ" is Valid. Valid
# Password "x@hcSeSplC" is Invalid. Missing Numbers
# Password "MiA8UaG@rJ" is Valid. Valid
# Password "X61gSR#@WE2" is Valid. Valid
# Password "S7U@7LWOYCZ3" is Invalid. Missing Lowercase letters
# Password "wN!zZVxHsK" is Invalid. Missing Numbers
# Password "ldy6Gx9X8cOWYq3b" is Invalid. Missing Special characters (!, @, #)
# Password "!IR1nhUBNqMgomKJwRA" is Valid. Valid
# Password "hx!ZLlZ0jXS" is Valid. Valid
# Password "tOXNy#22cN" is Valid. Valid
# Password "fbD2PR" is Invalid. Less than 8 Characters
# Password "S7LK!YcDR6RF#F" is Valid. Valid
# Password "@uUfx93T2" is Valid. Valid
# Password "1Ifoi7HoZg5VnP" is Invalid. Missing Special characters (!, @, #)
# Password "G6rX4Rxx" is Invalid. Missing Special characters (!, @, #)
# Password "e6K6Vibm" is Invalid. Missing Special characters (!, @, #)
# Password "QwRhkNSM6JNl9yQOr" is Invalid. Missing Special characters (!, @, #)
# Password "B@7sfLJzNo" is Valid. Valid
# Password "E6ZLT!W6c8" is Valid. Valid
# Password "5!mt18MOHhVEPEkB" is Valid. Valid
# Password "KQ9O8B#chZoFx6!3t" is Valid. Valid
# Password "djRLui@i" is Invalid. Missing Numbers
# Password "9qo#Y#5kTV" is Valid. Valid
# Password "4@D9MP9" is Invalid. Less than 8 Characters
# Password "Bqpd0Ps!#g@J" is Valid. Valid
# Password "7SY4pTg#MdoM!gH" is Valid. Valid
# Password "h1SlMhAFEc!2a" is Valid. Valid
# Password "6y5!HRPhyYEd" is Valid. Valid
# Password "AQeFFnH#sjc8eqN" is Valid. Valid
# Password "gbnQzAgrcU6E0Sd" is Invalid. Missing Special characters (!, @, #)
# Password "u3e2CPbALF#A" is Valid. Valid
# Password "CvX4qRM3250" is Invalid. Missing Special characters (!, @, #)
# Password "vjFS9QrUxL@0U" is Valid. Valid
# Password "oOlfStnZWwCE22z" is Invalid. Missing Special characters (!, @, #)
# Password "wj1#!Xe8OhQA#9BU" is Valid. Valid
# Password "#YmjbVLceJe3na" is Valid. Valid
# Password "mB!FbDw0y91" is Valid. Valid
# Password "4O3oKHydSZ0v" is Invalid. Missing Special characters (!, @, #)
# Password "DZqudmZg1rd@" is Valid. Valid
# Password "IVn3zG81@" is Valid. Valid
# Password "pJ0i8P7XC8az9P" is Invalid. Missing Special characters (!, @, #)
# Password "b#dNspgsVj!u" is Invalid. Missing Numbers
# Password "eBa0500Q@i@X17XP0J" is Valid. Valid
# Password "Q7VtZdbReQnJX#5" is Valid. Valid
# Password "rX4JtsuXa0" is Invalid. Missing Special characters (!, @, #)
# Password "1ViUIWX4#5rrYFH5" is Valid. Valid
# Password "@XvALlvM#" is Invalid. Missing Numbers
# Password "xhPPd!##fdIL" is Invalid. Missing Numbers
# Password "in6rVlrN!r4F" is Valid. Valid
# Password "#G#I01LH0BBSrP#" is Valid. Valid
# Password "I#zLgF6f@mb82" is Valid. Valid
# Password "N5LP#XCg" is Valid. Valid
# Password "RNzx6q5ev5b" is Invalid. Missing Special characters (!, @, #)
# Password "lMdifD1" is Invalid. Less than 8 Characters
# Password "xqcDSbo4xGj" is Invalid. Missing Special characters (!, @, #)
# Password "AmvwsRr507Ita2N" is Invalid. Missing Special characters (!, @, #)
# Password "g9#wa@2A2" is Valid. Valid
# Password "GhBc@q0#vFC" is Valid. Valid
# Password "kdo@0mHD!KFF5ceKD5" is Valid. Valid
# Password "tal5OZDEn72lcGe9N1O" is Invalid. Missing Special characters (!, @, #)
# Password "zGacg!k" is Invalid. Less than 8 Characters
# Password "GLUwMJ#ppe7" is Valid. Valid
# Password "9XrU#h!xt#8f" is Valid. Valid
# Password "w7@KwzcDK48c" is Valid. Valid
# Password "wCCVX1!P83jPVrCT" is Valid. Valid
# Password "Y2cLhh!2#r2bVCM0" is Valid. Valid
# Password "2JGis9Gh0R8d96hWUFR" is Invalid. Missing Special characters (!, @, #)
# Password "h5b1Ma33Ey@B" is Valid. Valid
# Password "5dkjk4dJ@sC" is Valid. Valid
# Password "mes0KE2QSauVqE#0V" is Valid. Valid
# Password "XLHw4w!JwvrjUKOsv" is Valid. Valid
# Password "#GfbGwvi" is Invalid. Missing Numbers
# Password "JIUyNhWuzdqXx0" is Invalid. Missing Special characters (!, @, #)
# Password "pzfsCEu3uqqXRBMai70" is Invalid. Missing Special characters (!, @, #)
# Password "OtN2nsLq7ww" is Invalid. Missing Special characters (!, @, #)
# Password "pfn04uLp##sFH" is Valid. Valid
# Password "TKNb0Gj87qdOumN" is Invalid. Missing Special characters (!, @, #)
# Password "dk@ciipMhEAt587iI" is Valid. Valid
# Password "##82Jt##o" is Valid. Valid
# Password "vr#HhrjYWid!@HB7@" is Valid. Valid
# Password "WuedEiv#CIxX" is Invalid. Missing Numbers
# Password "#6PDkcaeKSrf#K@" is Valid. Valid
# Password "X55RNk@T2a" is Valid. Valid
# Password "!RfIJ1oiptG94mOah" is Valid. Valid
# Password "!@wm81X@" is Valid. Valid
# Password "9#HJ07WB" is Invalid. Missing Lowercase letters
# Password "qzRV0po8X7vbJdH" is Invalid. Missing Special characters (!, @, #)
# Password "QGJfT2872lRu" is Invalid. Missing Special characters (!, @, #)
# Password "HYbJmgY09q" is Invalid. Missing Special characters (!, @, #)
# Password "0CPVsTWE@mmj@SsbU" is Valid. Valid
# Password "NR!7wktRq8o1F" is Valid. Valid
# Password "cehakxIFT3jzq" is Invalid. Missing Special characters (!, @, #)
# Password "0G8xXez!4Ix0cbu9d4" is Valid. Valid
# Password "WY0AE0dSr5eje" is Invalid. Missing Special characters (!, @, #)
# Password "auTkLmpwTfn" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "XPX!eaZp" is Invalid. Missing Numbers
# Password "r0!65vUPQf7FX4" is Valid. Valid
# Password "gZeFpbHqg0S#zPcx" is Valid. Valid
# Password "GThkQs5ORfOs0f" is Invalid. Missing Special characters (!, @, #)
# Password "xel!IDa6gP6" is Valid. Valid
# Password "WkXaF#9bmuITC1QUHy" is Valid. Valid
# Password "lao!DOEuvJgzzn5" is Valid. Valid
# Password "w00oua!5XZV@" is Valid. Valid
# Password "#XJGj#y" is Invalid. Less than 8 Characters
# Password "uLgC@KxO4ewL" is Valid. Valid
# Password "yadQsJes1zdAILnoZ4" is Invalid. Missing Special characters (!, @, #)
# Password "VUJ0UCESb#V" is Valid. Valid
# Password "@kmBFkcRoU1FP55K" is Valid. Valid
# Password "swSfsjOM3" is Invalid. Missing Special characters (!, @, #)
# Password "1MvaNeILJ#VVyfeI" is Valid. Valid
# Password "bMTOpZaHGN2a" is Invalid. Missing Special characters (!, @, #)
# Password "Il5Ilvzne17x2LD" is Invalid. Missing Special characters (!, @, #)
# Password "BQ6heiVEjQG" is Invalid. Missing Special characters (!, @, #)
# Password "x!6VCh9qeT" is Valid. Valid
# Password "!In4IU8WXpdD7qZ" is Valid. Valid
# Password "dwRcShyvlU8" is Invalid. Missing Special characters (!, @, #)
# Password "a@A4ZZBUKTB494K860G" is Valid. Valid
# Password "6EkvIk7czYerLGF" is Invalid. Missing Special characters (!, @, #)
# Password "MfJDcDWewr5#r@Cg@" is Valid. Valid
# Password "CmnHUbgVecy" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "@ZpkRAipib" is Invalid. Missing Numbers
# Password "OPXv0gA3k#" is Valid. Valid
# Password "iOO#yR8" is Invalid. Less than 8 Characters
# Password "0qLWG!SsXPeC" is Valid. Valid
# Password "Uf1Nv1udI1ntz" is Invalid. Missing Special characters (!, @, #)
# Password "25Ys9lEsripCJkVtQ" is Invalid. Missing Special characters (!, @, #)
# Password "7U2ccRj6MNv2kLG" is Invalid. Missing Special characters (!, @, #)
# Password "tZSpHJtrEVkIF7tZL" is Invalid. Missing Special characters (!, @, #)
# Password "7FqnN3VJIJ" is Invalid. Missing Special characters (!, @, #)
# Password "buJG6V7Lgg@SF8Zo" is Valid. Valid
# Password "@IoyH7mhECSJQK@b13s" is Valid. Valid
# Password "ACmzf3lW0M@k1" is Valid. Valid
# Password "n5mH3GxeWfYV1" is Invalid. Missing Special characters (!, @, #)
# Password "r@jA4zaSEaUcdsF" is Valid. Valid
# Password "qLtVB8@" is Invalid. Less than 8 Characters
# Password "@0oC!ipWZfRQJv4oa3" is Valid. Valid
# Password "W@fJDoDo2bl" is Valid. Valid
# Password "5fEEg7ALD3" is Invalid. Missing Special characters (!, @, #)
# Password "295PwyZvWOta7e6B" is Invalid. Missing Special characters (!, @, #)
# Password "bzM97bMCCJWT" is Invalid. Missing Special characters (!, @, #)
# Password "qoTu5Drsi" is Invalid. Missing Special characters (!, @, #)
# Password "Wx51yA1W" is Invalid. Missing Special characters (!, @, #)
# Password "4wbqe9GP" is Invalid. Missing Special characters (!, @, #)
# Password "0wAQ#@A5mjADNl" is Valid. Valid
# Password "vJfd7Ez#" is Valid. Valid
# Password "WQ4sxDsmIXw#" is Valid. Valid
# Password "JDkPYGw!Tpv" is Invalid. Missing Numbers
# Password "aUm@Mw4HI8" is Valid. Valid
# Password "aQ!4iqoK51" is Valid. Valid
# Password "8OMIpWQBy7op" is Invalid. Missing Special characters (!, @, #)
# Password "BPUoczaA5erRsiu" is Invalid. Missing Special characters (!, @, #)
# Password "l#oKzQD" is Invalid. Less than 8 Characters
# Password "!93@EufzdW!w2ZOE5p" is Valid. Valid
# Password "hJyZQqnGsM@xM" is Invalid. Missing Numbers
# Password "XsJINR" is Invalid. Less than 8 Characters
# Password "13ZBDwtb#75K0V1" is Valid. Valid
# Password "z#ry2#i" is Invalid. Less than 8 Characters
# Password "fiFnwCUxGKErS9" is Invalid. Missing Special characters (!, @, #)
# Password "Wnq7dP0PwqmJcD" is Invalid. Missing Special characters (!, @, #)
# Password "#uXC#ro0cFcnH4Zd" is Valid. Valid
# Password "mlCP4ExJ7" is Invalid. Missing Special characters (!, @, #)
# Password "orF3C#I!IvZJ@e8" is Valid. Valid
# Password "7Zvs5P#1JfSdJRgT6W" is Valid. Valid
# Password "sc#WA#jKun1y" is Valid. Valid
# Password "XUclC1px@4yA5x" is Valid. Valid
# Password "g!bpZ!HL14C8G" is Valid. Valid
# Password "qZcFr##YP@rYOBDFM" is Invalid. Missing Numbers
# Password "bo99yb!i0IPG" is Valid. Valid
# Password "xBg9m0XAk#lsb6" is Valid. Valid
# Password "rEsbzMPbkWdo5YX" is Invalid. Missing Special characters (!, @, #)
# Password "IhkL527" is Invalid. Less than 8 Characters
# Password "326#wzpnYNZ" is Valid. Valid
# Password "O@IuOBq8Zc8Hy6" is Valid. Valid
# Password "cxWw5b2f#aFq" is Valid. Valid
# Password "zHqTEU!oTI7Ww" is Valid. Valid
# Password "ZxwQ!HgWJ" is Invalid. Missing Numbers
# Password "lpmjqXje@F7f3El3l!" is Valid. Valid
# Password "EhsDd#3dr" is Valid. Valid
# Password "fCh9436Nmq@Sg9c@Lr" is Valid. Valid
# Password "t!avUZIJodGmXD" is Invalid. Missing Numbers
# Password "X8B!pFZe" is Valid. Valid
# Password "Ygy3EMvP@QW1sWJP" is Valid. Valid
# Password "F!HeaRhNR6S8" is Valid. Valid
# Password "D7QQMrr3q" is Invalid. Missing Special characters (!, @, #)
# Password "WEfN9@jv6cu9" is Valid. Valid
# Password "mjsEfDBHBv@" is Invalid. Missing Numbers
# Password "3ivwOZ0BxO" is Invalid. Missing Special characters (!, @, #)
# Password "2xi@Yv7#oLVMr24y9" is Valid. Valid
# Password "eMG3L5MHPol9Cq@" is Valid. Valid
# Password "uJPsDKaS" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "sw1CW0Rk!DA" is Valid. Valid
# Password "pZlJ!VGyqxq6" is Valid. Valid
# Password "S68#m!iZOr" is Valid. Valid
# Password "OA2fc2jkl6" is Invalid. Missing Special characters (!, @, #)
# Password "JaS5Sx5pVmMwuoKt#" is Valid. Valid
# Password "86h0S2F9#6cZvHoWK" is Valid. Valid
# Password "REHNEgZ4H" is Invalid. Missing Special characters (!, @, #)
# Password "I4lB0VBwA!T4" is Valid. Valid
# Password "u8QZZIN0NX" is Invalid. Missing Special characters (!, @, #)
# Password "3P84LUoIX" is Invalid. Missing Special characters (!, @, #)
# Password "QVvRDEM!jdvos" is Invalid. Missing Numbers
# Password "NGIBt@BCi8" is Valid. Valid
# Password "qwiVtMB!w#c427L" is Valid. Valid
# Password "6V3cQkbdox" is Invalid. Missing Special characters (!, @, #)
# Password "M4Zu323vECj9Z" is Invalid. Missing Special characters (!, @, #)
# Password "Y@@l2xvLROfacb" is Valid. Valid
# Password "8X#5HoG3r1ItC3Db3i" is Valid. Valid
# Password "e2IUfwG5H" is Invalid. Missing Special characters (!, @, #)
# Password "@#!kEvm6Kc3ovt" is Valid. Valid
# Password "!U3jEkJSyWXzl" is Valid. Valid
# Password "OZe2doUaM2b3em" is Invalid. Missing Special characters (!, @, #)
# Password "gJ!Z6i4cxmg0iZXS8guq" is Valid. Valid
# Password "ZiqPr!G7" is Valid. Valid
# Password "IlZdH4EDwLz" is Invalid. Missing Special characters (!, @, #)
# Password "skig4rel4tSg00w7y" is Invalid. Missing Special characters (!, @, #)
# Password "f0kOwfXHACXGTPz8" is Invalid. Missing Special characters (!, @, #)
# Password "AWN6rYMSBZ" is Invalid. Missing Special characters (!, @, #)
# Password "G2GEXutS6BLoK9#" is Valid. Valid
# Password "KPTWZ2F056s!!" is Valid. Valid
# Password "1pQA7tq5SAtd3mH0A" is Invalid. Missing Special characters (!, @, #)
# Password "15@TWDBP" is Invalid. Missing Lowercase letters
# Password "@ZMyX7D" is Invalid. Less than 8 Characters
# Password "XrS6tqJ0P8p22YH" is Invalid. Missing Special characters (!, @, #)
# Password "WovjkvtHcL!" is Invalid. Missing Numbers
# Password "U!ZSp2N5" is Valid. Valid
# Password "fVB8VSK8BG0@A4ulLH1" is Valid. Valid
# Password "VUxHX!WxhILKJ4K" is Valid. Valid
# Password "!0fgHSIUE4CK3bY" is Valid. Valid
# Password "Fo0!CmtiO" is Valid. Valid
# Password "5@3LWKFE8QSPIBf" is Valid. Valid
# Password "RuABDo@8QyDU" is Valid. Valid
# Password "##W!@9uUhP9M" is Valid. Valid
# Password "0nY0Ktc6YWx7" is Invalid. Missing Special characters (!, @, #)
# Password "Tb5uUraP@pPMUE@hcZ" is Valid. Valid
# Password "vvB!q412rL48pH" is Valid. Valid
# Password "eCS0gK8pD@!dnEJ" is Valid. Valid
# Password "a6OQ@ClyTWrKg#7" is Valid. Valid
# Password "BV!w8TLW" is Valid. Valid
# Password "@dxnL!33J" is Valid. Valid
# Password "vmcdlf26UzdEAl@7" is Valid. Valid
# Password "NiX#O2BO" is Valid. Valid
# Password "jxc2ZBxn!XV" is Valid. Valid
# Password "Wl2EF98Y!" is Valid. Valid
# Password "aYe@rUZOtvq4ZzM" is Valid. Valid
# Password "P#tOKR5n#GX9pdjE" is Valid. Valid
# Password "Dhcl21q#3Y5qL0" is Valid. Valid
# Password "mBaJo7#E5vR" is Valid. Valid
# Password "QiBUA52ZIQCK" is Invalid. Missing Special characters (!, @, #)
# Password "CXBxY6Rr8Kawop3!" is Valid. Valid
# Password "hx1!e!3uKF4" is Valid. Valid
# Password "o7k1@2AwgQb#7nW9ZI7Q" is Valid. Valid
# Password "DZ!Zp4@YvqB" is Valid. Valid
# Password "4Ud!npUHzOWl1!Yw" is Valid. Valid
# Password "GcdA6f@UfbY4JO7j@nV" is Valid. Valid
# Password "Zt4kT1i5#Y@" is Valid. Valid
# Password "Ybqg!45J2JG" is Valid. Valid
# Password "7KWoiAyi" is Invalid. Missing Special characters (!, @, #)
# Password "b!F!7qVTRF" is Valid. Valid
# Password "Kbp3C0z9rCxMyYMm" is Invalid. Missing Special characters (!, @, #)
# Password "80fBwn6" is Invalid. Less than 8 Characters
# Password "02Uzos3MDEZwhe" is Invalid. Missing Special characters (!, @, #)
# Password "#kJApNb9#" is Valid. Valid
# Password "EhnE1!@wwjhDDCBO" is Valid. Valid
# Password "syAfmKKORO4xNzFO" is Invalid. Missing Special characters (!, @, #)
# Password "8TSxA52QKho@#b#" is Valid. Valid
# Password "i!jv3wW!qFttG39x" is Valid. Valid
# Password "iTngSkouk#wwbKFq" is Invalid. Missing Numbers
# Password "@Fn1Nt6sm3FO" is Valid. Valid
# Password "d5E1#ORdiBxKbT2#6" is Valid. Valid
# Password "iV2RP@ddWZ6rvRMqON" is Valid. Valid
# Password "acaxTkfH" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "OCp3cY2nRmC" is Invalid. Missing Special characters (!, @, #)
# Password "hcvn@tu6ozUcj" is Valid. Valid
# Password "CM@ciBCiwa7s4" is Valid. Valid
# Password "xkaT79rq" is Invalid. Missing Special characters (!, @, #)
# Password "w3R0dl#fnf3THnI" is Valid. Valid
# Password "GtfsmH#tdk00S" is Valid. Valid
# Password "UtWRhHT#1R2T" is Valid. Valid
# Password "2oY8UgPkQcGdi" is Invalid. Missing Special characters (!, @, #)
# Password "qIbzOsXDMX#Z" is Invalid. Missing Numbers
# Password "otT0Zc" is Invalid. Less than 8 Characters
# Password "IS9khArQ0" is Invalid. Missing Special characters (!, @, #)
# Password "b5LzACG2geeHZ@" is Valid. Valid
# Password "!X28lc3w" is Valid. Valid
# Password "S#Da4MO@SHm3" is Valid. Valid
# Password "8d6T7UG" is Invalid. Less than 8 Characters
# Password "wpJtXb7K79x0s@6Sn" is Valid. Valid
# Password "hPF@3Qbeo00j53" is Valid. Valid
# Password "u5E#Xpb9u" is Valid. Valid
# Password "kLnFJ3Y" is Invalid. Less than 8 Characters
# Password "PtSs4cjd87WTBE7t" is Invalid. Missing Special characters (!, @, #)
# Password "zfmH0h2a9M9WaQ!lfp" is Valid. Valid
# Password "tXeYPJJQOU0#1QlQ" is Valid. Valid
# Password "XZfj!xg7" is Valid. Valid
# Password "pxXdCw0#KJ9" is Valid. Valid
# Password "1EDo!AODO6CV6Ns@" is Valid. Valid
# Password "y5EJfGK@J1c" is Valid. Valid
# Password "mP5A!cndMBqfPs" is Valid. Valid
# Password "97e196rwpjoTOn1" is Invalid. Missing Special characters (!, @, #)
# Password "@13gC!9WPRZlzBt" is Valid. Valid
# Password "4L!wOE0SdMQ8XnzQ" is Valid. Valid
# Password "Cu2J0J@Hg" is Valid. Valid
# Password "!WVcwBqi" is Invalid. Missing Numbers
# Password "#Cz1wOt1FNH@jehNO#" is Valid. Valid
# Password "FHnlRfa!g3kXBJ!laa4B" is Valid. Valid
# Password "sZ0r6Fz" is Invalid. Less than 8 Characters
# Password "ksMR8bb!sZ" is Valid. Valid
# Password "2e870B7NxcMVg!eju" is Valid. Valid
# Password "2G@vmzaQskz" is Valid. Valid
# Password "3HWN5Ef0lCNgA" is Invalid. Missing Special characters (!, @, #)
# Password "M!gIFNRkAN7YlA" is Valid. Valid
# Password "h6T6yI@x@eynlEEHg!" is Valid. Valid
# Password "8dtqW#MsIjJu4ANsk" is Valid. Valid
# Password "DgBbdXZ8Cco3Z0i" is Invalid. Missing Special characters (!, @, #)
# Password "ttQ07M0mK!!6" is Valid. Valid
# Password "Y4HtX3@kNzNhIm" is Valid. Valid
# Password "gL6otfHaJuWMZg@nLC" is Valid. Valid
# Password "jh!kLzrSwFUL7jQRa" is Valid. Valid
# Password "7efPQeodb4" is Invalid. Missing Special characters (!, @, #)
# Password "1aNmE16np1O8ct3" is Invalid. Missing Special characters (!, @, #)
# Password "KSKLjq!HUGU0G" is Valid. Valid
# Password "iGPJzLKT!tcMkJpM3!" is Valid. Valid
# Password "G1qEWR1HNvoeK1xVdk" is Invalid. Missing Special characters (!, @, #)
# Password "5d@gFr7CXAl" is Valid. Valid
# Password "N#V#n6dZIGgKCONSX" is Valid. Valid
# Password "biK@A5cd" is Valid. Valid
# Password "JarHf@9YYumuXrKe!" is Valid. Valid
# Password "hGHxXA9GVKPIwj" is Invalid. Missing Special characters (!, @, #)
# Password "QOMYIcG7LW9zie" is Invalid. Missing Special characters (!, @, #)
# Password "R8Kacl7ckVepgy@lBGh0" is Valid. Valid
# Password "@ChoAkPQS" is Invalid. Missing Numbers
# Password "8sxFopj7rhY" is Invalid. Missing Special characters (!, @, #)
# Password "XZ8zJxN!" is Valid. Valid
# Password "lybDP#vYJii@" is Invalid. Missing Numbers
# Password "Rb4uBPPk7Sb4HQp6#" is Valid. Valid
# Password "E7tAC7#HFQbUsAV82kr" is Valid. Valid
# Password "zL4LwvY1aX1@U" is Valid. Valid
# Password "KIDB#oP0z" is Valid. Valid
# Password "1aFUlr6@AS#ktOcq" is Valid. Valid
# Password "mHuiZC7zL@A@4" is Valid. Valid
# Password "aykcplG@j" is Invalid. Missing Numbers
# Password "pDI8Q7o7rZQz1Y1ooeA" is Invalid. Missing Special characters (!, @, #)
# Password "LPd9#cnUMHE" is Valid. Valid
# Password "JfRi2FDLy#" is Valid. Valid
# Password "CLwic3@xA6o1L" is Valid. Valid
# Password "N26o2TQ4T#k0W" is Valid. Valid
# Password "l8J@XyrFWHo#cF" is Valid. Valid
# Password "7A8!B#A#i3#Ru" is Valid. Valid
# Password "DcD4TZm#DXsxn" is Valid. Valid
# Password "747V!nCV3be!YDC" is Valid. Valid
# Password "#mIxDrD3u" is Valid. Valid
# Password "ze1ad3EfExnqP" is Invalid. Missing Special characters (!, @, #)
# Password "zUVFrD7!WxytNKxuoB" is Valid. Valid
# Password "E#Icx60fMvue" is Valid. Valid
# Password "Oql9L#Yo6dkXtS@OaRx" is Valid. Valid
# Password "1G0TmQI1" is Invalid. Missing Special characters (!, @, #)
# Password "HXvd6pNY@" is Valid. Valid
# Password "6AJoLJZ" is Invalid. Less than 8 Characters
# Password "JX12MCk0l6u7SRUz" is Invalid. Missing Special characters (!, @, #)
# Password "Zzp3oEZ#WQlI@9lKG" is Valid. Valid
# Password "h#No#F2gtzk7L5!#Z" is Valid. Valid
# Password "Uyq2KqOn!pCL687c" is Valid. Valid
# Password "IHr8k@rSLGMwIJ@z" is Valid. Valid
# Password "6TBaNdah3CF5cIY" is Invalid. Missing Special characters (!, @, #)
# Password "lvlI#CYtRZDu!i" is Invalid. Missing Numbers
# Password "P4!@emR!" is Valid. Valid
# Password "t20YFBL4qW@jLw" is Valid. Valid
# Password "iGrqcq@ihVvwveQS4J" is Valid. Valid
# Password "PLIhZ9oFB7i#" is Valid. Valid
# Password "q@EL2aUtuIEK0yE7" is Valid. Valid
# Password "ScsBE4UYZ7n" is Invalid. Missing Special characters (!, @, #)
# Password "Vm@Z9lkk" is Valid. Valid
# Password "I7vo9T6hi#9ajER1lOK" is Valid. Valid
# Password "!z1Q7WKRZ293Iin" is Valid. Valid
# Password "tV91WrM@mIka7l" is Valid. Valid
# Password "jerJe0!YOGp2q" is Valid. Valid
# Password "Y#1Hx#5#0" is Valid. Valid
# Password "r8fmErEh" is Invalid. Missing Special characters (!, @, #)
# Password "#aLq89vhSAOQiq" is Valid. Valid
# Password "pA1GeySGosWcWpg" is Invalid. Missing Special characters (!, @, #)
# Password "8WioGwmMq@#i!" is Valid. Valid
# Password "s!zOoQi9!0GER66" is Valid. Valid
# Password "t15T#x6I#" is Valid. Valid
# Password "i2c7p1SFw@qO@" is Valid. Valid
# Password "JfY7JOFp96Eax" is Invalid. Missing Special characters (!, @, #)
# Password "Vu9e0@4EnrPS#oG" is Valid. Valid
# Password "M5aCOaG6QItfsyjvdER" is Invalid. Missing Special characters (!, @, #)
# Password "YZ#Fe463OZuBt3eu" is Valid. Valid
# Password "P#Obre0GVwI" is Valid. Valid
# Password "5LhM!!spX1" is Valid. Valid
# Password "yTv@XnAQBXogH8XCRAT" is Valid. Valid
# Password "P2dMdx10sF#TFGH" is Valid. Valid
# Password "PaK#oR3Ukth" is Valid. Valid
# Password "2Eu3a1HS" is Invalid. Missing Special characters (!, @, #)
# Password "PDjOOhQ8ejl#uDF" is Valid. Valid
# Password "!Wr7nRbPkGXOpN@JQwF" is Valid. Valid
# Password "hm#TV!ZfYB2!" is Valid. Valid
# Password "!M8NL#aa4PdG" is Valid. Valid
# Password "37#JDyAt0KE05" is Valid. Valid
# Password "J2K#nSJskm" is Valid. Valid
# Password "SIn2sRQ2" is Invalid. Missing Special characters (!, @, #)
# Password "x8fVcD8FxlxnDVA" is Invalid. Missing Special characters (!, @, #)
# Password "@#Np!LSR06NHFY0HR" is Valid. Valid
# Password "9PxZz1q!8" is Valid. Valid
# Password "AkIC#9OATrfmwbr5M" is Valid. Valid
# Password "ofIAoPQ" is Invalid. Less than 8 Characters
# Password "wWto9BSkl8WR6!43#" is Valid. Valid
# Password "vXGaimac1WAt" is Invalid. Missing Special characters (!, @, #)
# Password "#AXKQUU3oDpDGi#evw" is Valid. Valid
# Password "9caNnYBSYX1" is Invalid. Missing Special characters (!, @, #)
# Password "t#!M#0nv3" is Valid. Valid
# Password "2FMUxFe@g" is Valid. Valid
# Password "6ybnO!Q0W" is Valid. Valid
# Password "SO#O0#wBJ4BT@" is Valid. Valid
# Password "jJM5aQIkA69NQK!!1d" is Valid. Valid
# Password "h#ygyTOPsJCZ@z" is Invalid. Missing Numbers
# Password "K00hEh0Il" is Invalid. Missing Special characters (!, @, #)
# Password "Z1XGHc4h6ubAa96U" is Invalid. Missing Special characters (!, @, #)
# Password "Xv3IjuC!SCf0" is Valid. Valid
# Password "@WQiRfBoSUSNbqhp!j" is Invalid. Missing Numbers
# Password "CLZ#kHa02#Wzg" is Valid. Valid
# Password "wwqXt08y1b@8E" is Valid. Valid
# Password "MSjrlLWgDKOY8Z" is Invalid. Missing Special characters (!, @, #)
# Password "xnh#qGX7" is Valid. Valid
# Password "V4tJ7m8f!gB" is Valid. Valid
# Password "nD@hz5w1" is Valid. Valid
# Password "m4mfd59Ek9yUpT@fj" is Valid. Valid
# Password "7@DKzSI4Z!frdg" is Valid. Valid
# Password "HSea1W00x3!R4qX4K" is Valid. Valid
# Password "jQ@6MlgIcv6abNNsUlC" is Valid. Valid
# Password "v9mEJCuAigI9wY1Y" is Invalid. Missing Special characters (!, @, #)
# Password "5CP4sgFgS" is Invalid. Missing Special characters (!, @, #)
# Password "s@aW0MBfa" is Valid. Valid
# Password "YF60TpS3R#FaeZlpv" is Valid. Valid
# Password "6mzeIC18@mXmH2" is Valid. Valid
# Password "TRd2htYKTPI" is Invalid. Missing Special characters (!, @, #)
# Password "l@97cFWdb2xz9NyUYf!" is Valid. Valid
# Password "h63#fie9@t" is Invalid. Missing Uppercase letters
# Password "0PoIEHNdABZzyqO7rr2" is Invalid. Missing Special characters (!, @, #)
# Password "V0tF!xYecV3uDKJo" is Valid. Valid
# Password "Fll@9@YIPwV2v1d29P" is Valid. Valid
# Password "D!ydujFzVeg0GVlZH" is Valid. Valid
# Password "LGFrCyRLCn0JyhHR" is Invalid. Missing Special characters (!, @, #)
# Password "DYZDzYMl" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "MtocNnC29vqo" is Invalid. Missing Special characters (!, @, #)
# Password "5onn!jJ" is Invalid. Less than 8 Characters
# Password "Y84qF#459" is Valid. Valid
# Password "54YGfmOeEoITL#Gj" is Valid. Valid
# Password "9OdmwwV5N!@ly" is Valid. Valid
# Password "I90qgMyBsIDw0oYlDf2" is Invalid. Missing Special characters (!, @, #)
# Password "Hox3Wic!X@uj7pae" is Valid. Valid
# Password "xyM9@p1k8o" is Valid. Valid
# Password "6zKpdMfQ2zzunet2R!" is Valid. Valid
# Password "WDXUq5DiSKj74" is Invalid. Missing Special characters (!, @, #)
# Password "93locNWiElAdL2h" is Invalid. Missing Special characters (!, @, #)
# Password "lwUbqcq@gQDGP56WwSr" is Valid. Valid
# Password "AOk0xaw!lE" is Valid. Valid
# Password "y#7ZjXo1cfI" is Valid. Valid
# Password "#!LNwKzWY1NhXBx8l" is Valid. Valid
# Password "mNyav5lyI@pQAy" is Valid. Valid
# Password "yDH3@!0XC6GI" is Valid. Valid
# Password "w86UEh5" is Invalid. Less than 8 Characters
# Password "1yNRTgT4TLppy" is Invalid. Missing Special characters (!, @, #)
# Password "Pltn6YybP13e!n" is Valid. Valid
# Password "7ZiD@knKpeLm" is Valid. Valid
# Password "!ZulVF47ej" is Valid. Valid
# Password "uBl8b!wqs2" is Valid. Valid
# Password "WbinuOzW" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "pJbCRxa7KeKcV6Ox" is Invalid. Missing Special characters (!, @, #)
# Password "dQ6ZqDzgR4Na8a" is Invalid. Missing Special characters (!, @, #)
# Password "SH#ty2Jp2tZ2bRF" is Valid. Valid
# Password "QV5N0K2II" is Invalid. Missing Lowercase letters, Missing Special characters (!, @, #)
# Password "gavI2IXcQlr" is Invalid. Missing Special characters (!, @, #)
# Password "ij#2a7RVlo9TbRdJ" is Valid. Valid
# Password "7JacYP" is Invalid. Less than 8 Characters
# Password "fttsRRDU5W" is Invalid. Missing Special characters (!, @, #)
# Password "BbBgF83cU@" is Valid. Valid
# Password "d#Zo36y1f4clIBu23N4" is Valid. Valid
# Password "!5hGHGDe" is Valid. Valid
# Password "V6c7BTu" is Invalid. Less than 8 Characters
# Password "cNp7!wt2fX8nMv" is Valid. Valid
# Password "fmvqat79ln2RL" is Invalid. Missing Special characters (!, @, #)
# Password "ODe!pZX6@HwVGM7uaX" is Valid. Valid
# Password "9JUIv83" is Invalid. Less than 8 Characters
# Password "NXh4Y960ZIR3" is Invalid. Missing Special characters (!, @, #)
# Password "v4JYWQoz0yorwMQD" is Invalid. Missing Special characters (!, @, #)
# Password "JMrA1gaI8pS!" is Valid. Valid
# Password "sHODlZgr8lj9i" is Invalid. Missing Special characters (!, @, #)
# Password "zrnQvg#yez@t!r8a" is Valid. Valid
# Password "HBqNOaxmuwx2" is Invalid. Missing Special characters (!, @, #)
# Password "@J0iXoYcE7cCkPE!" is Valid. Valid
# Password "tW0qiP4rKCetvCb" is Invalid. Missing Special characters (!, @, #)
# Password "HONt6#yTzoN" is Valid. Valid
# Password "9HW6s9!Bv!HRYvD" is Valid. Valid
# Password "vA30nBWAb72D" is Invalid. Missing Special characters (!, @, #)
# Password "#XS3sGNK25XlOg@KoM" is Valid. Valid
# Password "9L1Tn8m6#lzF" is Valid. Valid
# Password "75#5RKx1a" is Valid. Valid
# Password "o8Vjzzsu4twtz" is Invalid. Missing Special characters (!, @, #)
# Password "KBhizF#DXl0rp6Q" is Valid. Valid
# Password "P8FwCeNTKrhWx" is Invalid. Missing Special characters (!, @, #)
# Password "6Uew###Bm6K" is Valid. Valid
# Password "slWVYAS#a" is Invalid. Missing Numbers
# Password "EUyzQlQ12k!" is Valid. Valid
# Password "q6AAhsQifzRTa" is Invalid. Missing Special characters (!, @, #)
# Password "Ckk#D2SxeyL" is Valid. Valid
# Password "@hYyJ75hvxkDD9gql" is Valid. Valid
# Password "ezj13qC@KJ" is Valid. Valid
# Password "ig2Y!PLYu2f2Z0f" is Valid. Valid
# Password "VIICfjsmU0K4n1l5" is Invalid. Missing Special characters (!, @, #)
# Password "Tr6wAM7WR" is Invalid. Missing Special characters (!, @, #)
# Password "X9Jps8Ec1w8" is Invalid. Missing Special characters (!, @, #)
# Password "r3xJKuAS5quTqLx" is Invalid. Missing Special characters (!, @, #)
# Password "@qy4I19Hw" is Valid. Valid
# Password "F@NFF7mncZXUVVkqA" is Valid. Valid
# Password "ts3cGEqdp" is Invalid. Missing Special characters (!, @, #)
# Password "bmQ!fkIAF" is Invalid. Missing Numbers
# Password "aqg@PbkYMJprVohLee" is Invalid. Missing Numbers
# Password "m!r3zBqXaAsic19C3" is Valid. Valid
# Password "4RC6hyyrT62dozX" is Invalid. Missing Special characters (!, @, #)
# Password "o@A6zBGkJVTPG" is Valid. Valid
# Password "wy5AAPo9g@0@QfVq" is Valid. Valid
# Password "0Nu6795kwF9wIs@n#xO" is Valid. Valid
# Password "Eh4NpL8R##oP4" is Valid. Valid
# Password "UAXq9yQacyVYb" is Invalid. Missing Special characters (!, @, #)
# Password "7EE0I77admvJ5jE5" is Invalid. Missing Special characters (!, @, #)
# Password "#xpNif0t" is Valid. Valid
# Password "X40dUHfkszwF1d4" is Invalid. Missing Special characters (!, @, #)
# Password "M@ryaAwWKQL28W" is Valid. Valid
# Password "#Z6vJ@rHXumf1" is Valid. Valid
# Password "3vsydSC!zQ" is Valid. Valid
# Password "jVsb!eC" is Invalid. Less than 8 Characters
# Password "g#!Le2!ND0FHjQsHFy" is Valid. Valid
# Password "ThRPl@E#@1" is Valid. Valid
# Password "RyaOhdXP0BqcM9z!v4KV" is Valid. Valid
# Password "DqHhySKpefE7r426" is Invalid. Missing Special characters (!, @, #)
# Password "8yRiO@Tsk" is Valid. Valid
# Password "TIN4DwDf@i8!" is Valid. Valid
# Password "im!YMX#yEAUaIEnerO" is Invalid. Missing Numbers
# Password "uipxtjdvqvq5" is Invalid. Missing Uppercase letters, Missing Special characters (!, @, #)
# Password "qusAShCgtD" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "S0mJiA2K" is Invalid. Missing Special characters (!, @, #)
# Password "rlMW1CGoC!" is Valid. Valid
# Password "mC@rsa0FlTsaZpRo7" is Valid. Valid
# Password "AWPc038Pzeob@" is Valid. Valid
# Password "D9CIHk!oAn9K3B@3" is Valid. Valid
# Password "E!VM9b7AOnts" is Valid. Valid
# Password "BQ8zdlDJ07H1lC" is Invalid. Missing Special characters (!, @, #)
# Password "qsm8YAfTmg15" is Invalid. Missing Special characters (!, @, #)
# Password "uhd9coAl" is Invalid. Missing Special characters (!, @, #)
# Password "8svbniJyqUkm0dztT" is Invalid. Missing Special characters (!, @, #)
# Password "KO!wUYqlAXv4uSddT" is Valid. Valid
# Password "V!IoXffoBsgA" is Invalid. Missing Numbers
# Password "@PYR3NND4SVfl" is Valid. Valid
# Password "TAhI2g5NJY4UtEyY@" is Valid. Valid
# Password "OByiI1HA5WXDc0hQUf" is Invalid. Missing Special characters (!, @, #)
# Password "5YGZcNpL" is Invalid. Missing Special characters (!, @, #)
# Password "nHDnHFDGVnYfv" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "AuzxH9RKg1S#rZ58" is Valid. Valid
# Password "VpE59o1fgWv#ICGS" is Valid. Valid
# Password "z!oP@#FW" is Invalid. Missing Numbers
# Password "pFZuCyi1yeV3p8j@s" is Valid. Valid
# Password "i@pc9NlSlM1" is Valid. Valid
# Password "be0VS!nxxZtLRz" is Valid. Valid
# Password "@m1Wk1@O" is Valid. Valid
# Password "cf0Zs74g31M" is Invalid. Missing Special characters (!, @, #)
# Password "23XiIvtLB" is Invalid. Missing Special characters (!, @, #)
# Password "BlDt#gR0SamEbg9a!s" is Valid. Valid
# Password "Zp5ftCn#lhwk8El@Lnx" is Valid. Valid
# Password "6JrmNC1A4" is Invalid. Missing Special characters (!, @, #)
# Password "w!jIj3azJR4MU" is Valid. Valid
# Password "!wpLdyEW4#3p" is Valid. Valid
# Password "WX2SGcS2" is Invalid. Missing Special characters (!, @, #)
# Password "@wNhx6F7OQ9RixBt" is Valid. Valid
# Password "OPRgcN98w@9Qoz" is Valid. Valid
# Password "AFluj3JaZRmTl2E" is Invalid. Missing Special characters (!, @, #)
# Password "V@ARFJuZ" is Invalid. Missing Numbers
# Password "fA40@LW1o5" is Valid. Valid
# Password "QPa37rGt9uc" is Invalid. Missing Special characters (!, @, #)
# Password "q#Yg1wg!" is Valid. Valid
# Password "@dRhe4bFc8F3#6Wi" is Valid. Valid
# Password "7#pKVuz0" is Valid. Valid
# Password "hcoQkfl0#ydV!ECb5" is Valid. Valid
# Password "E8W1yiIji7QI9@" is Valid. Valid
# Password "XiL#Kv8sEUK!Q@Ydk" is Valid. Valid
# Password "Kj3RHm#U@gm9" is Valid. Valid
# Password "JaH@rZ0VC" is Valid. Valid
# Password "CljOqjvd7hjg@PgQF" is Valid. Valid
# Password "ca@Ih!rL" is Invalid. Missing Numbers
# Password "#L2DZ9EoNob7RTgff" is Valid. Valid
# Password "Jvr#kKle!92tTqI" is Valid. Valid
# Password "ChvNrdME" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "UQkxr!ecf!" is Invalid. Missing Numbers
# Password "ljBGOrZDEEjtHX6" is Invalid. Missing Special characters (!, @, #)
# Password "akxdqCCgcF8" is Invalid. Missing Special characters (!, @, #)
# Password "iKFPTt!iNgcXy0I" is Valid. Valid
# Password "#JFbX#g8gn" is Valid. Valid
# Password "YFNOK4Ob" is Invalid. Missing Special characters (!, @, #)
# Password "HM0pPj7HnjAclXN" is Invalid. Missing Special characters (!, @, #)
# Password "wmYyJgULh" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "l#bbgOZ9ATtcfc2Ta" is Valid. Valid
# Password "AtyePE5qF" is Invalid. Missing Special characters (!, @, #)
# Password "0PdEgSZy1TrWHHn" is Invalid. Missing Special characters (!, @, #)
# Password "iZnxM53yf!n8xERX" is Valid. Valid
# Password "#ivorRTq@fmf4xvv" is Valid. Valid
# Password "oZ5aQ#lVGRgj" is Valid. Valid
# Password "wRdGas4W2!" is Valid. Valid
# Password "dJUAIgaBk43Lc3vW@" is Valid. Valid
# Password "98w9LiPzch" is Invalid. Missing Special characters (!, @, #)
# Password "pkGK4sLwLiHSW05u2U" is Invalid. Missing Special characters (!, @, #)
# Password "Mbckh9wK8aRvpKbD" is Invalid. Missing Special characters (!, @, #)
# Password "F2sBzCEj@XJAYO" is Valid. Valid
# Password "zMUoZkyM7nwrk" is Invalid. Missing Special characters (!, @, #)
# Password "RgtR@xyB@" is Invalid. Missing Numbers
# Password "meNXXkI@A5tT" is Valid. Valid
# Password "IAqGa4t2gW6uo0ae!" is Valid. Valid
# Password "FVkS13F@1xIA" is Valid. Valid
# Password "M1iC5oyh2hK" is Invalid. Missing Special characters (!, @, #)
# Password "lraL0C@p5uC60B2B@" is Valid. Valid
# Password "4ZLb61Yz0KhYVOPgX" is Invalid. Missing Special characters (!, @, #)
# Password "01ROVVBBF0bT0JpCq" is Invalid. Missing Special characters (!, @, #)
# Password "7rxivJ23gGQ3gioZC" is Invalid. Missing Special characters (!, @, #)
# Password "LLTceUUuD7g@TV45" is Valid. Valid
# Password "sw7@FMIU5y!ibN0Dh" is Valid. Valid
# Password "Jv6E5pwlWBsVaoesx@" is Valid. Valid
# Password "NA#v2kknm2s49If5M2" is Valid. Valid
# Password "3CNtLNd4Wzkv7" is Invalid. Missing Special characters (!, @, #)
# Password "A9R0Y#Rq0w" is Valid. Valid
# Password "hSFHzrjnKTSJ2xS" is Invalid. Missing Special characters (!, @, #)
# Password "vbI5D3qajA" is Invalid. Missing Special characters (!, @, #)
# Password "1sNISkOm@8RBqml" is Valid. Valid
# Password "CCj2IIjwBFqgid" is Invalid. Missing Special characters (!, @, #)
# Password "!wz280n" is Invalid. Less than 8 Characters
# Password "0ke@Hx!Gt5#SXH1" is Valid. Valid
# Password "5hf7bMBE9P#g" is Valid. Valid
# Password "E!B67mpW8kBag!Ap" is Valid. Valid
# Password "Fy77Qfxc4x5kl@" is Valid. Valid
# Password "Q3yry!TIaKJ8mB" is Valid. Valid
# Password "SVn3j7h!B!8IJ#n7sNA" is Valid. Valid
# Password "m@egFOCb3Ui" is Valid. Valid
# Password "gapAsV0E!TUBXK0" is Valid. Valid
# Password "D!HAQ8dL#Wl" is Valid. Valid
# Password "ox8H3@uOgVnsScc" is Valid. Valid
# Password "09jiNOii" is Invalid. Missing Special characters (!, @, #)
# Password "lBvgj@WVwU2fZ7gQ!" is Valid. Valid
# Password "@Hbpu7!lQu" is Valid. Valid
# Password "SxNZ0fgSicBNr" is Invalid. Missing Special characters (!, @, #)
# Password "7554KMvx" is Invalid. Missing Special characters (!, @, #)
# Password "lSGu4lQtE!" is Valid. Valid
# Password "g!tADKDNhrVe3WFA" is Valid. Valid
# Password "snN9SPDq8pEz9" is Invalid. Missing Special characters (!, @, #)
# Password "L!UYqMcox1" is Valid. Valid
# Password "6tza2kV5" is Invalid. Missing Special characters (!, @, #)
# Password "cX#Oe!2DbYWjthJaDa" is Valid. Valid
# Password "P14jLWa4x@a" is Valid. Valid
# Password "fAR0rU0eak6" is Invalid. Missing Special characters (!, @, #)
# Password "qNHOQ9u@#zU" is Valid. Valid
# Password "HK0E2jLj789D" is Invalid. Missing Special characters (!, @, #)
# Password "YFO9t66ZsoHUw9m" is Invalid. Missing Special characters (!, @, #)
# Password "O#3SSsR@aaP" is Valid. Valid
# Password "j7hLPH26SjzAhYwWYr" is Invalid. Missing Special characters (!, @, #)
# Password "6EJzhPrnnD" is Invalid. Missing Special characters (!, @, #)
# Password "XYTOBUyamBEo" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "l2rQqB" is Invalid. Less than 8 Characters
# Password "YS#lNAs2" is Valid. Valid
# Password "!uc20nl8DdS!" is Valid. Valid
# Password "rv77I5CQ" is Invalid. Missing Special characters (!, @, #)
# Password "XmhngUGT13SE2w" is Invalid. Missing Special characters (!, @, #)
# Password "FHBvb#go2kmK!" is Valid. Valid
# Password "rTqqWcT98GVWo8" is Invalid. Missing Special characters (!, @, #)
# Password "#NzEhES1XA8eIq@O" is Valid. Valid
# Password "ajFqQ#n!iimve" is Invalid. Missing Numbers
# Password "@tBclI5cwQcH#4wK" is Valid. Valid
# Password "MHF2aZCZ53b5G" is Invalid. Missing Special characters (!, @, #)
# Password "K1toL9OvXjjIaK4PSb" is Invalid. Missing Special characters (!, @, #)
# Password "dIgjKm#@fL1VbcOGWi" is Valid. Valid
# Password "84SyER0DETyV" is Invalid. Missing Special characters (!, @, #)
# Password "m9pM1!6TK" is Valid. Valid
# Password "!q#wT5@uWx" is Valid. Valid
# Password "Ql#8bEpYL4lTIMdPrQh" is Valid. Valid
# Password "S3oguLSg2Irq@" is Valid. Valid
# Password "UZ51qS7F" is Invalid. Missing Special characters (!, @, #)
# Password "rGsU0I6d" is Invalid. Missing Special characters (!, @, #)
# Password "BeSCOrv4!WRhKEXS" is Valid. Valid
# Password "TQY4qdV" is Invalid. Less than 8 Characters
# Password "0zYAW7K!eYG" is Valid. Valid
# Password "v66VIgyzLtXeW" is Invalid. Missing Special characters (!, @, #)
# Password "UfG!fga3aomw#@" is Valid. Valid
# Password "fp1uJloK4zr1iR" is Invalid. Missing Special characters (!, @, #)
# Password "vPx2v9Q8RHwx5Wj" is Invalid. Missing Special characters (!, @, #)
# Password "wey9KoHThRSrFQzWw" is Invalid. Missing Special characters (!, @, #)
# Password "wXb5PQSA3syJX@" is Valid. Valid
# Password "nNNyT!IWapcV4BcgtvF" is Valid. Valid
# Password "8ol@HB@0WMqT" is Valid. Valid
# Password "V7RV6!!CA" is Invalid. Missing Lowercase letters
# Password "I9E06SvAj@uqS" is Valid. Valid
# Password "K36LM40Xccv9euHPK5" is Invalid. Missing Special characters (!, @, #)
# Password "kFZCH1YEY!pPtL" is Valid. Valid
# Password "3!kx5TFcV2" is Valid. Valid
# Password "p7PTuQy@YNkE7wBoqR" is Valid. Valid
# Password "g#nKudmnynbQQ6ZtU" is Valid. Valid
# Password "zqwQBEgrRWYqCqI9V" is Invalid. Missing Special characters (!, @, #)
# Password "zRSHO#5VnWJ" is Valid. Valid
# Password "HZvnfiI#iG32#m" is Valid. Valid
# Password "a1s6fbSwi@Au#" is Valid. Valid
# Password "Wxm@x2EtVnj6z9xPlBB" is Valid. Valid
# Password "3b@QPBb" is Invalid. Less than 8 Characters
# Password "LaprEWMQhM7190HO@e8J" is Valid. Valid
# Password "iq4JaGJ!8B4q5LUJR" is Valid. Valid
# Password "6U2wirPylccmf@eH8" is Valid. Valid
# Password "n#Hb2l0n" is Valid. Valid
# Password "9#ktbJRwpdkgpq" is Valid. Valid
# Password "MH!XqmCTi11e85k" is Valid. Valid
# Password "W7ToYYtgEozDASSaNi" is Invalid. Missing Special characters (!, @, #)
# Password "jycO1Q6#@2FdvV5KhR" is Valid. Valid
# Password "BpLZtqIp#PfQxF@x0" is Valid. Valid
# Password "XFfd#y!en8n8gFThNC@" is Valid. Valid
# Password "ochIPnqI" is Invalid. Missing Numbers, Missing Special characters (!, @, #)
# Password "!jwItS" is Invalid. Less than 8 Characters
# Password "9O80xsSxaC" is Invalid. Missing Special characters (!, @, #)
# Password "GHIY5vQJAc#WSyQ" is Valid. Valid
# Password "j1!ADODML9dU" is Valid. Valid
#
# Total Valid Passwords: 605
# Total Invalid Passwords: 395

# %% [markdown]
# # Generate input file with 1000 random passowrds

# %%
import random
import string

def generate_password():
    length = random.randint(6, 16)  # Some short, some valid length
    password = ''.join(random.choices(string.ascii_letters + string.digits + "!@#", k=length))

    # Randomize Criteria Distribution
    if random.choice([True, False]):
        password += random.choice(string.ascii_uppercase)
    if random.choice([True, False]):
        password += random.choice(string.ascii_lowercase)
    if random.choice([True, False]):
        password += random.choice(string.digits)
    if random.choice([True, False]):
        password += random.choice("!@#")

    return ''.join(random.sample(password, len(password)))  # Shuffle

# Generate 1000 passwords
passwords = [generate_password() for _ in range(1000)]

# Create File input.txt
with open("input.txt", "w") as file:
    file.write("\n".join(passwords))

print("input.txt with 1000 passwords has been generated!")
# Out:
# input.txt with 1000 passwords has been generated!
